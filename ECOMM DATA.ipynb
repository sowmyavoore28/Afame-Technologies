# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # ORDERS
# - ROW ID: A unique identifier for each row in the dataset.
# - Order ID: A unique identifier for each order.
# - Order Date: The date on which the order was placed.
# - Ship Date: The date on which the order was shipped.
# - Ship Mode: The shipping mode used for the order.
# - Customer ID: A unique identifier for each customer.
# - Customer Name: The name of the customer who placed the order.
# - Segment: The market segment to which the customer belongs.
# - City: The city in which the customer is located.
# - State: The state in which the customer is located.
# - Country: The country in which the customer is located.
# - Market: The market in which the order was placed.
# - Postal Code: The postal code of the customer's location.
# - Region: The region in which the customer is located.
# - Product ID: A unique identifier for each product.
# - Category: The category to which the product belongs.
# - Sub-Category: The sub-category to which the product belongs.
# - Product Name: The name of the product.
# - Sales: The total sales amount for the order.
# - Quantity: The quantity of the product ordered.
# - Discount: The discount applied to the order.
# - Shipping Cost: The cost of shipping the order.
# - Profit: The profit earned from the order.
# - Order Priority: The priority of the order.

# %%
df1=pd.read_excel('ECOMM DATA.xlsx',sheet_name='Orders')
df1.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %% [markdown]
# # RETURNS
# - Returned :The person who return the order.
# - Order ID :The unique identification number which is used to identify the customer name and details of the product.
# - Market :The market in which the order was placed.

# %%
df2=pd.read_excel('ECOMM DATA.xlsx',sheet_name='Returns')
df2.head()
# Out:
#   Returned         Order ID         Market
# 0      Yes   MX-2013-168137          LATAM
# 1      Yes   US-2011-165316          LATAM
# 2      Yes  ES-2013-1525878             EU
# 3      Yes   CA-2013-118311  United States
# 4      Yes  ES-2011-1276768             EU

# %% [markdown]
# # PEOPLE
# - Person :The name of the person who order.
# - Region :The place where person make an order

# %%
df3=pd.read_excel('ECOMM DATA.xlsx',sheet_name='People')
df3
# Out:
#                   Person          Region
# 0          Anna Andreadi         Central
# 1            Chuck Magee           South
# 2         Kelly Williams            East
# 3         Matt Collister            West
# 4      Deborah Brumfield          Africa
# 5           Larry Hughes            EMEA
# 6          Nicole Hansen          Canada
# 7       Giulietta Dortch       Caribbean
# 8             Nora Preis    Central Asia
# 9            Jack Lebron           North
# 10       Shirley Daniels      North Asia
# 11        Anthony Jacobs         Oceania
# 12  Alejandro Ballentine  Southeast Asia

# %% [markdown]
# # BASIC CHECKS

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %% [markdown]
# - Null values present in the postal code.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Returned  1173 non-null   object
#  1   Order ID  1173 non-null   object
#  2   Market    1173 non-null   object
# dtypes: object(3)
# memory usage: 27.6+ KB

# %% [markdown]
# - In this table there are details about the how many orders returned.
# - There are no null values.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Person  13 non-null     object
#  1   Region  13 non-null     object
# dtypes: object(2)
# memory usage: 340.0+ bytes

# %% [markdown]
# - In this table there details about the peoples
# - There are no null values present

# %%
df1.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375818
# std      174.340972      57.296810
# min    -6599.978000       0.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
df2.describe()
# Out:
#        Returned        Order ID Market
# count      1173            1173   1173
# unique        1            1172      4
# top         Yes  US-2014-136679  LATAM
# freq       1173               2    297

# %%
df3.describe()
# Out:
#                Person   Region
# count              13       13
# unique             13       13
# top     Anna Andreadi  Central
# freq                1        1

# %%
df1.describe(include='O')
# Out:
#               Order ID       Ship Mode Customer ID    Customer Name   Segment  \
# count            51290           51290       51290            51290     51290
# unique           25035               4        1590              795         3
# top     CA-2014-100111  Standard Class    PO-18850  Muhammed Yedwab  Consumer
# freq                14           30775          97              108     26518
#
#                  City       State        Country Market   Region  \
# count           51290       51290          51290  51290    51290
# unique           3636        1094            147      7       13
# top     New York City  California  United States   APAC  Central
# freq              915        2001           9994  11002    11117
#
#              Product ID         Category Sub-Category Product Name  \
# count             51290            51290        51290        51290
# unique            10292                3           17         3788
# ...

# %%
#Identifying the null value Percentage
percent_missing = df1.isnull().sum() * 100 / len(df1)
percent_missing
# Out:
# Row ID             0.00000
# Order ID           0.00000
# Order Date         0.00000
# Ship Date          0.00000
# Ship Mode          0.00000
# Customer ID        0.00000
# Customer Name      0.00000
# Segment            0.00000
# City               0.00000
# State              0.00000
# Country            0.00000
# Postal Code       80.51472
# Market             0.00000
# Region             0.00000
# Product ID         0.00000
# Category           0.00000
# Sub-Category       0.00000
# Product Name       0.00000
# Sales              0.00000
# Quantity           0.00000
# Discount           0.00000
# Profit             0.00000
# Shipping Cost      0.00000
# Order Priority     0.00000
# dtype: float64

# %% [markdown]
# - There are 80 percentage values are missing which we cannot manipulate.so dropping this column

# %%
#dropping column
df1.drop(df1.columns[11],axis=1,inplace=True)

# %% [markdown]
# # RENAMING COLUMNS

# %%
df1.rename(columns={'Postal Code':'Postal_Code'},inplace=True)

# %%
df1.rename(columns = {'Order ID':'Order_ID'}, inplace = True)

# %%
df1.rename(columns = {'Order Date':'Order_Date'}, inplace = True)

# %%
df1.rename(columns={'Ship Date':'Ship_Date'},inplace=True)

# %%
df1.rename(columns={'Ship Mode':'Ship_Mode'},inplace=True)

# %%
df1.rename(columns={'Customer ID':'Customer_ID'},inplace=True)

# %%
df1.rename(columns={'Postal Code':'Postal_Code'},inplace=True)

# %%
df1.rename(columns={'Product ID':'Product_ID'},inplace=True)

# %%
df1.rename(columns={'Product Name':'Product_Name'},inplace=True)

# %%
df1.rename(columns={'Order Priority':'Order_Priority'},inplace=True)

# %%
df1.rename(columns={'Customer Name':'Customer_Name'},inplace=True)

# %%
df1.rename(columns={'Sub-Category':'Sub_Category'},inplace=True)

# %%
df1.rename(columns={'Shipping Cost':'Shipping_Cost'},inplace=True)

# %%
df1.rename(columns={'Order Priority':'Order_Priority'},inplace=True)

# %%
df1.head()
# Out:
#    Row ID         Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer_Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product_ID    Category Sub_Category  \
# ...

# %% [markdown]
# # VALUES IN COLUMNS

# %%
df1.Customer_Name.value_counts()
# Out:
# Muhammed Yedwab    108
# Steven Ward        106
# Gary Hwang         102
# Patrick O'Brill    102
# Bill Eplett        102
#                   ...
# Emily Burns         35
# David Bremer        34
# Darren Budd         31
# Nicole Brennan      31
# Michael Oakman      29
# Name: Customer_Name, Length: 795, dtype: int64

# %%
df1.Ship_Mode.value_counts()
# Out:
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: Ship_Mode, dtype: int64

# %%
df1.Customer_Name.value_counts()
# Out:
# Muhammed Yedwab    108
# Steven Ward        106
# Gary Hwang         102
# Patrick O'Brill    102
# Bill Eplett        102
#                   ...
# Emily Burns         35
# David Bremer        34
# Darren Budd         31
# Nicole Brennan      31
# Michael Oakman      29
# Name: Customer_Name, Length: 795, dtype: int64

# %%
df1.Segment.value_counts()
# Out:
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: Segment, dtype: int64

# %%
df1.City.value_counts()
# Out:
# New York City     915
# Los Angeles       747
# Philadelphia      537
# San Francisco     510
# Santo Domingo     443
#                  ...
# Vesoul              1
# Várzea Grande       1
# Luanshya            1
# Kissimmee           1
# Victoria Falls      1
# Name: City, Length: 3636, dtype: int64

# %%
df1.State.value_counts()
# Out:
# California            2001
# England               1499
# New York              1128
# Texas                  985
# Ile-de-France          981
#                       ...
# Lambayeque               1
# Aveiro                   1
# Lima                     1
# Medea                    1
# Matabeleland North       1
# Name: State, Length: 1094, dtype: int64

# %%
df1.Country.value_counts()
# Out:
# United States    9994
# Australia        2837
# France           2827
# Mexico           2644
# Germany          2065
#                  ...
# Bahrain             2
# South Sudan         2
# Chad                2
# Burundi             2
# Eritrea             2
# Name: Country, Length: 147, dtype: int64

# %%
df1.Market.value_counts()
# Out:
# APAC      11002
# LATAM     10294
# EU        10000
# US         9994
# EMEA       5029
# Africa     4587
# Canada      384
# Name: Market, dtype: int64

# %%
df1.Region.value_counts()
# Out:
# Central           11117
# South              6645
# EMEA               5029
# North              4785
# Africa             4587
# Oceania            3487
# West               3203
# Southeast Asia     3129
# East               2848
# North Asia         2338
# Central Asia       2048
# Caribbean          1690
# Canada              384
# Name: Region, dtype: int64

# %%
df1.Category.value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: Category, dtype: int64

# %%
df1.Sub_Category.value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: Sub_Category, dtype: int64

# %%
df1.Order_Priority.value_counts()
# Out:
# Medium      29433
# High        15501
# Critical     3932
# Low          2424
# Name: Order_Priority, dtype: int64

# %% [markdown]
# # CREATING NEW COLUMNS

# %%
df1['Month_Name']=df1.Ship_Date.dt.month_name()
df1['Year']=df1.Ship_Date.dt.year

# %%
df1.Month_Name=df1.Month_Name.map({'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12})#imputation using map function

# %%
df1.head()
# Out:
#    Row ID         Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer_Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#   Sub_Category                                       Product_Name     Sales  \
# ...

# %% [markdown]
# # Average of sales by year

# %%
total_sales=df1.groupby('Year')['Sales'].mean()
total_sales
# Out:
# Year
# 2011    251.713168
# 2012    243.941813
# 2013    246.186161
# 2014    246.284657
# 2015    210.272081
# Name: Sales, dtype: float64

# %% [markdown]
# - More sales are happen in the year of 2011

# %% [markdown]
# # Best selling product and the total sales

# %%
product_sales=df1.groupby('Category')['Sales'].sum()
best_selling_product = product_sales.idxmax()
best_selling_product_sales = product_sales.max()
print("Best-selling product:", best_selling_product)
print("Total sales:", best_selling_product_sales)
# Out:
# Best-selling product: Technology
# Total sales: 4744557.49808

# %% [markdown]
# - Most selling product is Technology and sales are 4744557.49808

# %%
# Average sales according by month
sales_month=df1.groupby('Month_Name')['Sales'].mean()
sales_month
# Out:
# Month_Name
# 1     254.922994
# 2     250.160269
# 3     258.472679
# 4     227.609051
# 5     232.559032
# 6     242.263576
# 7     240.060253
# 8     250.340404
# 9     244.122945
# 10    263.644574
# 11    238.708591
# 12    254.047685
# Name: Sales, dtype: float64

# %% [markdown]
# -  Average Sales according to the month

# %%
# Average sales according to the city 
sales_city=df1.groupby('City')['Sales'].mean()
sales_city
# Out:
# City
# Aachen                   223.714765
# Aalen                    979.695000
# Aalst                     96.832500
# Aba                       42.564960
# Abadan                   123.177273
#                             ...
# Zwedru                    49.410000
# Zwickau                   33.010000
# Zwolle                    75.292500
# eMbalenhle                37.950000
# Águas Lindas de Goiás     46.740000
# Name: Sales, Length: 3636, dtype: float64

# %%
# Average sales according to the region
sales_region=df1.groupby('Region')['Sales'].mean()
sales_region
# Out:
# Region
# Africa            170.868370
# Canada            174.292109
# Caribbean         191.882166
# Central           253.872674
# Central Asia      367.591097
# EMEA              160.302508
# East              238.336110
# North             260.849656
# North Asia        362.835663
# Oceania           315.510356
# South             240.919043
# Southeast Asia    282.653617
# West              226.493233
# Name: Sales, dtype: float64

# %%
# Average sales according to the state
sales_state=df1.groupby('State')['Sales'].mean()
sales_state
# Out:
# State
# 'Ajman       52.497000
# 'Amman      179.199750
# 'Asir       200.437500
# Abia         42.564960
# Abruzzi     373.541667
#                ...
# Zinder       90.682500
# Zulia       116.914916
# Zürich      344.345294
# Šiauliai     24.140250
# Žilina       30.060000
# Name: Sales, Length: 1094, dtype: float64

# %%
# Average sales according by segment
sales_segment=df1.groupby('Segment')['Sales'].mean()
sales_segment
# Out:
# Segment
# Consumer       245.416299
# Corporate      247.890176
# Home Office    247.228403
# Name: Sales, dtype: float64

# %%
# Average profit according to the month
profit_in_month=df1.groupby('Month_Name')['Profit'].mean()
profit_in_month
# Out:
# Month_Name
# 1     27.463518
# 2     33.307784
# 3     31.184275
# 4     23.402872
# 5     27.677040
# 6     27.019074
# 7     26.752971
# 8     29.386654
# 9     29.284806
# 10    34.549152
# 11    28.270238
# 12    26.492619
# Name: Profit, dtype: float64

# %%
profit_in_year=df1.groupby('Year')['Profit'].mean()
profit_in_year
# Out:
# Year
# 2011    27.594401
# 2012    28.086643
# 2013    29.632615
# 2014    28.690810
# 2015    26.052480
# Name: Profit, dtype: float64

# %%
Maximum_sales_by_state = df1.groupby('State')['Sales'].max().sort_values(ascending=False).head(10)
Maximum_sales_by_state
# Out:
# State
# Florida         22638.480
# Indiana         17499.950
# Washington      13999.960
# New York        11199.968
# Delaware        10499.970
# Michigan         9892.740
# Minnesota        9449.950
# New Jersey       9099.930
# Virginia         8749.950
# Pennsylvania     8399.976
# Name: Sales, dtype: float64

# %%
Maximum_profit_by_country = df1.groupby('Country')['Profit'].max().sort_values(ascending=False).head(10)
Maximum_profit_by_country
# Out:
# Country
# United States     8399.976
# Italy             3979.080
# Japan             2939.310
# India             2817.990
# Morocco           2597.280
# Spain             2476.440
# United Kingdom    2461.320
# New Zealand       2447.100
# Australia         2316.510
# France            1868.130
# Name: Profit, dtype: float64

# %%
Maximum_sales_by_city = df1.groupby('City')['Sales'].max().sort_values(ascending=False).head(10)
Maximum_sales_by_city
# Out:
# City
# Jacksonville     22638.480
# Lafayette        17499.950
# Seattle          13999.960
# New York City    11199.968
# Newark           10499.970
# Detroit           9892.740
# Minneapolis       9449.950
# Lakewood          9099.930
# Arlington         8749.950
# Philadelphia      8399.976
# Name: Sales, dtype: float64

# %%
Maximum_Profit_by_city = df1.groupby('City')['Profit'].max().sort_values(ascending=False).head(10)
Maximum_Profit_by_city
# Out:
# City
# Lafayette        8399.9760
# Seattle          6719.9808
# Newark           5039.9856
# Detroit          4946.3700
# Minneapolis      4630.4755
# Prato            3979.0800
# New York City    3919.9888
# Atlanta          3177.4750
# Fuji             2939.3100
# Kota             2817.9900
# Name: Profit, dtype: float64

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mean_sales_by_region = df1.groupby('Region')['Sales'].mean()
# Plotting
plt.figure(figsize=(10,6))
axr = sns.barplot(x=mean_sales_by_region.index, y=mean_sales_by_region.values, palette='coolwarm')
axr.bar_label(axr.containers[0])
plt.xlabel('Region')
plt.ylabel('Mean Sales')
plt.title('Mean Sales by Region')
plt.xticks(rotation=45)  
plt.show()

# %%
categories = df1['Category'].unique()
sales = df1['Sales'].mean()
# Create the bar plot
ax= plt.bar(categories, sales)
plt.bar_label(ax)
plt.xlabel('Category')
plt.ylabel('Average Sales')
plt.title('Sales by Category')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.lineplot(x=df1.Year,y=df1.Sales,marker='o', linestyle='--',errorbar=None,color='r')
plt.title('Sales by year')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df1.Year,y=df1.Profit,marker='o', linestyle='-.',errorbar=None)
plt.title('Profit by year')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(df1,x=df1.Market,y=df1.Sales,errorbar=None,marker='o', linestyle=':',color='g')
plt.title('Sales by market')
plt.show()

# %%
import matplotlib.pyplot as plt
market=df1['Market'].value_counts()
plt.pie(market,labels=market.index,autopct='%1.1f%%',shadow=True,explode=[0.1,0,0,0,0.1,0.2,0.5])
plt.title('Market')
plt.show()

# %%
Orderpriority=df1['Order_Priority'].value_counts()
plt.pie(Orderpriority,labels=Orderpriority.index,autopct='%1.1f%%',shadow=True,explode=[0,0.1,0.2,0.2])
plt.show()

# %%
shipmode=df1['Ship_Mode'].value_counts()
plt.pie(shipmode,labels=shipmode.index,autopct='%1.1f%%',shadow=True,explode=[0,0.1,0.2,0.2])
plt.show()

# %%
axs=sns.countplot(x=df1.Segment,palette ="BuPu")
axs.bar_label(axs.containers[0])

plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(x=df1.Sub_Category,palette='RdYlBu')
ax.bar_label(ax.containers[0])

plt.xticks(rotation=45)
plt.show()

# %%
df1['Discount'] = df1['Discount'].round(2) 
plt.figure(figsize=(10,8))
axd=sns.barplot(x='Discount', y='Sales', data=df1.sort_values(by='Discount'))
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.title('Sales by Discount')
plt.show()

# %%
axq=sns.countplot(x=df1.Quantity,palette='Set3')
axq.bar_label(axq.containers[0])

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df1.Month_Name,y=df1.Profit,errorbar=None,marker='o', linestyle='--',color='g')
# Out:
# <Axes: xlabel='Month_Name', ylabel='Profit'>

# %%
df2.shape
# Out:
# (1173, 3)

# %%
axm=sns.countplot(x=df2.Market,palette='Set2')
axm.bar_label(axm.containers[0])

plt.show()

# %% [markdown]
# - Average sales by region are central Asia:367.567,North Asia :362.836,oceania:315.51 ,South Asia:282.654,North:260.85
# - Maximum Average profit in year 2013 and less average profit in 2015
# - Maximum Sales in year in 2014 and less in 2015.
# - Best selling product is Technology.
# - Most selling is happened inthe month of october.
# - Moost profit is in the month of october.
# - Maximum sales in state of Florida.
# - Maximum profit in country of United States.

# %% [markdown]
# # Percentage of returns

# %%
total_returns = df2[df2['Returned'] == 'Yes']['Order ID'].nunique()

total_sold = df1['Order_ID'].nunique()

return_percentage = (total_returns / total_sold) * 100

print("Percentage of returns: {:.2f}%".format(return_percentage))
# Out:
# Percentage of returns: 4.68%

# %% [markdown]
# There are only 4.68 percentage of orders are returned.

# %%
#dropping the rows
df1.drop(['Row ID','Order_ID','Customer_ID','Customer_Name','Product_ID','Product_Name'], axis= 1,inplace=True)

# %%
df1
# Out:
#       Order_Date  Ship_Date       Ship_Mode      Segment           City  \
# 0     2012-07-31 2012-07-31        Same Day     Consumer  New York City
# 1     2013-02-05 2013-02-07    Second Class    Corporate     Wollongong
# 2     2013-10-17 2013-10-18     First Class     Consumer       Brisbane
# 3     2013-01-28 2013-01-30     First Class  Home Office         Berlin
# 4     2013-11-05 2013-11-06        Same Day     Consumer          Dakar
# ...          ...        ...             ...          ...            ...
# 51285 2014-06-19 2014-06-19        Same Day    Corporate           Kure
# 51286 2014-06-20 2014-06-24  Standard Class     Consumer        Houston
# 51287 2013-12-02 2013-12-02        Same Day  Home Office         Oxnard
# 51288 2012-02-18 2012-02-22  Standard Class  Home Office       Valinhos
# 51289 2012-05-22 2012-05-26    Second Class     Consumer       Tipitapa
#
#                  State        Country  Market      Region         Category  \
# ...

# %%
num_col=df1.select_dtypes(include = ['float64', 'int64'])
num_col
# Out:
#           Sales  Quantity  Discount    Profit  Shipping_Cost  Month_Name  Year
# 0      2309.650         7       0.0  762.1845        933.570           7  2012
# 1      3709.395         9       0.1 -288.7650        923.630           2  2013
# 2      5175.171         9       0.1  919.9710        915.490          10  2013
# 3      2892.510         5       0.1  -96.5400        910.160           1  2013
# 4      2832.960         8       0.0  311.5200        903.040          11  2013
# ...         ...       ...       ...       ...            ...         ...   ...
# 51285    65.100         5       0.0    4.5000          0.010           6  2014
# 51286     0.444         1       0.8   -1.1100          0.010           6  2014
# 51287    22.920         3       0.0   11.2308          0.010          12  2013
# 51288    13.440         2       0.0    2.4000          0.003           2  2012
# 51289    61.380         3       0.0    1.8000          0.002           5  2012
#
# ...

# %%
cat_col=df1.select_dtypes(include = ['object'])
cat_col
# Out:
#             Ship_Mode      Segment           City            State  \
# 0            Same Day     Consumer  New York City         New York
# 1        Second Class    Corporate     Wollongong  New South Wales
# 2         First Class     Consumer       Brisbane       Queensland
# 3         First Class  Home Office         Berlin           Berlin
# 4            Same Day     Consumer          Dakar            Dakar
# ...               ...          ...            ...              ...
# 51285        Same Day    Corporate           Kure        Hiroshima
# 51286  Standard Class     Consumer        Houston            Texas
# 51287        Same Day  Home Office         Oxnard       California
# 51288  Standard Class  Home Office       Valinhos        São Paulo
# 51289    Second Class     Consumer       Tipitapa          Managua
#
#              Country  Market      Region         Category Sub_Category  \
# 0      United States      US        East       Technology  Accessories
# ...

# %%
plt.figure(figsize=(20,12))
for i,col in enumerate(num_col.columns, start=1):
    plt.subplot(3,3,i)
    sns.kdeplot(x=col,data=num_col,fill=True,color='g')
    plt.xlabel(col,fontsize=12)
    plt.xticks()
    plt.ylabel('Number of data',fontsize=12)
plt.show()

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
for col in cat_col.columns:
    df1[col] = encoder.fit_transform(df1[col])

# %%
df1
# Out:
#       Order_Date  Ship_Date  Ship_Mode  Segment  City  State  Country  Market  \
# 0     2012-07-31 2012-07-31          1        0  2290    703      139       6
# 1     2013-02-05 2013-02-07          2        1  3518    702        6       0
# 2     2013-10-17 2013-10-18          0        0   497    820        6       0
# 3     2013-01-28 2013-01-30          0        2   375    145       47       4
# 4     2013-11-05 2013-11-06          1        0   857    270      110       1
# ...          ...        ...        ...      ...   ...    ...      ...     ...
# 51285 2014-06-19 2014-06-19          1        1  1726    410       65       0
# 51286 2014-06-20 2014-06-24          3        0  1400    982      139       6
# 51287 2013-12-02 2013-12-02          1        2  2408    192      139       6
# 51288 2012-02-18 2012-02-22          3        2  3346    955       17       5
# 51289 2012-05-22 2012-05-26          2        0  3224    599       92       5
#
# ...

# %%
df1.drop(['Order_Date','Ship_Date'],axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ship_Mode       51290 non-null  int32
#  1   Segment         51290 non-null  int32
#  2   City            51290 non-null  int32
#  3   State           51290 non-null  int32
#  4   Country         51290 non-null  int32
#  5   Market          51290 non-null  int32
#  6   Region          51290 non-null  int32
#  7   Category        51290 non-null  int32
#  8   Sub_Category    51290 non-null  int32
#  9   Sales           51290 non-null  float64
#  10  Quantity        51290 non-null  int64
#  11  Discount        51290 non-null  float64
#  12  Profit          51290 non-null  float64
#  13  Shipping_Cost   51290 non-null  float64
#  14  Order_Priority  51290 non-null  int32
#  15  Month_Name      51290 non-null  int64
#  16  Year            51290 non-null  int64
# ...

# %%
df1['Month_Name'] = df1['Month_Name'].astype('object')

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
df1[['City','State','Country','Sales','Profit','Shipping_Cost']]=scale.fit_transform(df1[['City','State','Country','Sales','Profit','Shipping_Cost']])

# %% [markdown]
# # Correlation

# %%
corr_n =num_col.corr()

plt.figure(figsize=(25,15), dpi=200)

sns.heatmap(corr_n, cmap="Blues",annot=True)
# Out:
# <Axes: >

# %%
df1
# Out:
#        Ship_Mode  Segment      City     State   Country  Market  Region  \
# 0              1        0  0.629986  0.643184  0.952055       6       6
# 1              2        1  0.967813  0.642269  0.041096       0       9
# 2              0        0  0.136726  0.750229  0.041096       0       9
# 3              0        2  0.103164  0.132662  0.321918       4       3
# 4              1        0  0.235763  0.247027  0.753425       1       0
# ...          ...      ...       ...       ...       ...     ...     ...
# 51285          1        1  0.474828  0.375114  0.445205       0       8
# 51286          3        0  0.385144  0.898445  0.952055       6       3
# 51287          1        2  0.662448  0.175663  0.952055       6      12
# 51288          3        2  0.920495  0.873742  0.116438       5      10
# 51289          2        0  0.886933  0.548033  0.630137       5       3
#
#        Category  Sub_Category     Sales  Quantity  Discount    Profit  \
# ...

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score, KFold, train_test_split

# %%
X = df1.drop(['Sales'],axis=1)
y = df1.Sales

# split data to train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 20)

# %% [markdown]
# # LINEAR REGRESSION

# %%
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
print(f"train score: {model.score(X_train, y_train)}")
# score for test 
print(f"test score: {model.score(X_test, y_test)}")
# Out:
# train score: 0.7025961289895185
# test score: 0.6187872941007979

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)  # RMSE is the square root of MSE
print(f"\nMean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 0.005434516658942346
# Mean Squared Error: 0.00020447722367039582
# Root Mean Squared Error: 0.014299553268210717

# %%
r2 = r2_score(y_test, y_pred)
print(f"Coefficient of Determination (R^2): {r2}")
# Out:
# Coefficient of Determination (R^2): 0.6187872941007979

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Gradiant Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
G_model=GradientBoostingRegressor()
G_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
G_ypred=G_model.predict(X_test)

# %%
print(f"Mean Absolute Error: {mean_absolute_error(y_test,G_ypred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,G_ypred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,G_ypred))}")
print(f"R2 Score: {r2_score(y_test,G_ypred)}")
# Out:
# Mean Absolute Error: 0.0028940338276298105
# Mean Squared Error: 0.00011247456824604097
# Root Mean Squared Error: 0.01060540278565793
# R2 Score: 0.7903104622790053

# %% [markdown]
# # RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
R_model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
R_model.fit (X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_jobs=-1)

# %%
R_ypred=R_model.predict(X_test)

# %%
print(f"Mean Absolute Error: {mean_absolute_error(y_test,R_ypred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,R_ypred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,R_ypred))}")
print(f"R2 Score: {r2_score(y_test,R_ypred)}")
# Out:
# Mean Absolute Error: 0.002836559807293443
# Mean Squared Error: 0.00012010931303027699
# Root Mean Squared Error: 0.01095943944872533
# R2 Score: 0.7760767903530801
